# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/ABC/Desktop/task1/Dataset .csv")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
#group by city and calculate average cost
df.groupby("City")["Average Cost for two"].mean()
# Out:
# City
# Abu Dhabi           182.000000
# Agra               1065.000000
# Ahmedabad           857.142857
# Albany               19.750000
# Allahabad           517.500000
#                       ...
# Weirton              25.000000
# Wellington City      71.250000
# Winchester Bay       25.000000
# Yorkton              25.000000
# ��stanbul            81.428571
# Name: Average Cost for two, Length: 141, dtype: float64

# %%
df.groupby("City")["Average Cost for two"].mean().sort_values(ascending= False).head()
# Out:
# City
# Jakarta       308437.500000
# Tangerang     250000.000000
# Bogor         160000.000000
# Bandung       150000.000000
# Pasay City      3333.333333
# Name: Average Cost for two, dtype: float64

# %%
df.groupby("City")["Average Cost for two"].mean().sort_values(ascending= False).head().plot(kind ="bar")
plt.title("Average Cost for two per city, top 5")
plt.xlabel("City")
plt.ylabel("Amount")
plt.show()

# %%
#cuisines total no. of votes
data = df.groupby("Cuisines")["Votes"].sum().reset_index()

# %%
data
# Out:
#                                        Cuisines  Votes
# 0                                       Afghani     39
# 1                     Afghani, Mughlai, Chinese      2
# 2                         Afghani, North Indian      0
# 3     Afghani, North Indian, Pakistani, Arabian      3
# 4                                       African    373
# ...                                         ...    ...
# 1820                       Western, Asian, Cafe    259
# 1821                 Western, Fusion, Fast Food     32
# 1822                              World Cuisine     95
# 1823            World Cuisine, Mexican, Italian    115
# 1824            World Cuisine, Patisserie, Cafe   1034
#
# [1825 rows x 2 columns]

# %%
data[data["Votes"] != 0]
# Out:
#                                        Cuisines  Votes
# 0                                       Afghani     39
# 1                     Afghani, Mughlai, Chinese      2
# 3     Afghani, North Indian, Pakistani, Arabian      3
# 4                                       African    373
# 5                           African, Portuguese    265
# ...                                         ...    ...
# 1820                       Western, Asian, Cafe    259
# 1821                 Western, Fusion, Fast Food     32
# 1822                              World Cuisine     95
# 1823            World Cuisine, Mexican, Italian    115
# 1824            World Cuisine, Patisserie, Cafe   1034
#
# [1777 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
sns.pairplot(df[["Average Cost for two", "Aggregate rating", "Votes"]])

# %%
df["Has Online delivery"].value_counts()
# Out:
# Has Online delivery
# No     7100
# Yes    2451
# Name: count, dtype: int64

# %%
df["Has Online delivery"].value_counts().plot(kind = "pie")
plt.title("Has Online delivery?")
plt.ylabel("")
plt.legend()
plt.show()

# %%
df[["Aggregate rating","Rating text"]].sort_values(by="Aggregate rating", ascending= True).head(2300)
# Out:
#       Aggregate rating Rating text
# 6615               0.0   Not rated
# 1994               0.0   Not rated
# 1995               0.0   Not rated
# 1996               0.0   Not rated
# 1997               0.0   Not rated
# ...                ...         ...
# 8716               2.4        Poor
# 4953               2.4        Poor
# 1771               2.4        Poor
# 8467               2.4        Poor
# 6616               2.4        Poor
#
# [2300 rows x 2 columns]

# %%
df = df[df["Rating text"] != "Not rated"]

# %%
df["Rating text"].value_counts().plot(kind ="pie")
plt.title("Rating averages")
plt.ylabel("")
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
X= df[["Average Cost for two","Has Table booking", "Has Online delivery", "Price range"]]

# %%
#Above 2 below 2.5 Poor
#Above 2.5 below 3.5 Average
#Above 3.5 below 4.0 Good
#Above 4 below 4.5 Very good
#Above 4.5 Excellent

# %%
y = df[["Aggregate rating"]]

# %%
X
# Out:
#       Average Cost for two Has Table booking Has Online delivery  Price range
# 0                     1100               Yes                  No            3
# 1                     1200               Yes                  No            3
# 2                     4000               Yes                  No            4
# 3                     1500                No                  No            4
# 4                     1500               Yes                  No            4
# ...                    ...               ...                 ...          ...
# 9546                    80                No                  No            3
# 9547                   105                No                  No            3
# 9548                   170                No                  No            4
# 9549                   120                No                  No            4
# 9550                    55                No                  No            2
#
# [7403 rows x 4 columns]

# %%
from sklearn import preprocessing
labelencoder = preprocessing.LabelEncoder()

# %%
X["Has Table booking"] = labelencoder.fit_transform(X["Has Table booking"])
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_11892\3860357707.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Has Table booking"] = labelencoder.fit_transform(X["Has Table booking"])

# %%
X
# Out:
#       Average Cost for two  Has Table booking Has Online delivery  Price range
# 0                     1100                  1                  No            3
# 1                     1200                  1                  No            3
# 2                     4000                  1                  No            4
# 3                     1500                  0                  No            4
# 4                     1500                  1                  No            4
# ...                    ...                ...                 ...          ...
# 9546                    80                  0                  No            3
# 9547                   105                  0                  No            3
# 9548                   170                  0                  No            4
# 9549                   120                  0                  No            4
# 9550                    55                  0                  No            2
#
# [7403 rows x 4 columns]

# %%
labelencoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
X["Has Online delivery"]= labelencoder.fit_transform(X["Has Online delivery"])
# Out:
# C:\Users\ABC\AppData\Local\Temp\ipykernel_11892\784965737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Has Online delivery"]= labelencoder.fit_transform(X["Has Online delivery"])

# %%
X
# Out:
#       Average Cost for two  Has Table booking  Has Online delivery  \
# 0                     1100                  1                    0
# 1                     1200                  1                    0
# 2                     4000                  1                    0
# 3                     1500                  0                    0
# 4                     1500                  1                    0
# ...                    ...                ...                  ...
# 9546                    80                  0                    0
# 9547                   105                  0                    0
# 9548                   170                  0                    0
# 9549                   120                  0                    0
# 9550                    55                  0                    0
#
#       Price range
# 0               3
# 1               3
# 2               4
# 3               4
# 4               4
# ...           ...
# 9546            3
# ...

# %%
labelencoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
#has table booking 0 is no 1 is yes
#has online delivery 0 is no 1 is yes

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
X= scaler.fit_transform(X)

# %%
X
# Out:
# array([[-0.0190367 ,  2.37978283, -0.68302371,  1.10671644],
#        [-0.0135729 ,  2.37978283, -0.68302371,  1.10671644],
#        [ 0.13941344,  2.37978283, -0.68302371,  2.18135204],
#        ...,
#        [-0.06985002, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07258191, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07613338, -0.42020641, -0.68302371,  0.03208084]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
import numpy as np

# %%
def modelresults(predictions):
    print("Mean absolute error on model is {}".format(mean_absolute_error(y_test,predictions)))
    print("Root mean squared error on model is {}".format(np.sqrt(mean_squared_error(y_test,predictions))))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictionsfromlr = lr.predict(X_test)

# %%
modelresults(predictionsfromlr)
# Out:
# Mean absolute error on model is 0.3914732502686916
# Root mean squared error on model is 0.4926207687493576

# %%
predictionsfromlr
# Out:
# array([[3.22634936],
#        [3.22621384],
#        [3.41893487],
#        ...,
#        [3.41900263],
#        [3.22641712],
#        [3.2262816 ]])

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
svrmodel = SVR()

# %%
param_gridsvr = {"C" : [0.1,0.5], "kernel" : ["linear","poly"], "degree":[2]}

# %%
gridsvr = GridSearchCV(svrmodel,param_gridsvr)
gridsvr.fit(X_train,y_train)
# Out:
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
predsgridsvr = gridsvr.predict(X_test)

# %%
modelresults(predsgridsvr)
# Out:
# Mean absolute error on model is 0.3871582370497908
# Root mean squared error on model is 0.4929209143539656

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
param_grid = {
    "max_depth" : [10,30],
    "min_samples_leaf" : [1,2],
    "min_samples_split" : [2,5]
}

# %%
treemodel = DecisionTreeRegressor()

# %%
grid_tree = GridSearchCV(estimator = treemodel, param_grid = param_grid)

# %%
grid_tree.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [10, 30], 'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5]})

# %%
treepredictions = grid_tree.predict(X_test)

# %%
modelresults(treepredictions)
# Out:
# Mean absolute error on model is 0.3536129275521156
# Root mean squared error on model is 0.45247479897352066

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfrmodel = RandomForestRegressor()

# %%
param_gridrfr = {"max_depth" :[5,15], "n_estimators" : [2,5,10]}

# %%
gridrfr = GridSearchCV(rfrmodel, param_gridrfr)

# %%
gridrfr.fit(X_train,y_train)
# Out:
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
randomforestpredictions = gridrfr.predict(X_test)

# %%
modelresults(randomforestpredictions)
# Out:
# Mean absolute error on model is 0.35270241448689676
# Root mean squared error on model is 0.45099205762065264

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 10}

# %%
grid_tree.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}

# %%
from sklearn.neighbors import KNeighborsRegressor
knn = KNeighborsRegressor()
knn_param_grid = {"n_neighbors": [3,5,7,9]}
knn_grid_search = GridSearchCV(knn, knn_param_grid)

# %%
knn_grid_search.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsRegressor(),
#              param_grid={'n_neighbors': [3, 5, 7, 9]})

# %%
knnpreds = knn_grid_search.predict(X_test)

# %%
modelresults(knnpreds)
# Out:
# Mean absolute error on model is 0.37918073373846495
# Root mean squared error on model is 0.4809439587637991

# %%
knn_grid_search.best_params_
# Out:
# {'n_neighbors': 9}

# %%
from sklearn.ensemble import AdaBoostRegressor
ada = AdaBoostRegressor()
ada_param_grid = {"n_estimators" :[50,100,200],
                  "learning_rate" :[0.1,0.5,1]}
ada_grid_search = GridSearchCV(ada, ada_param_grid)

# %%
ada_grid_search.fit(X_train,y_train)
# Out:
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
adapreds = ada_grid_search.predict(X_test)

# %%
modelresults(adapreds)
# Out:
# Mean absolute error on model is 0.36382255592263146
# Root mean squared error on model is 0.4622007225197569

# %%
gridrfr
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 15], 'n_estimators': [2, 5, 10]})

# %%
import joblib
joblib.dump(gridrfr, "mlmodel.pkl")
# Out:
# ['mlmodel.pkl']

# %%
scaler
# Out:
# StandardScaler()

# %%
joblib.dump(scaler,"Scaler.pkl")
# Out:
# ['Scaler.pkl']

# %%
#Evaluating the performance of all models

# %%
#training by linear regression algorithm
linreg = LinearRegression()
linreg.fit(X_train,y_train)
linreg_pred=linreg.predict(X_test)

# %%
#evaluating performance metrics of linear regression
linreg_mae = mean_absolute_error(y_test, linreg_pred)
linreg_mse = mean_squared_error(y_test, linreg_pred)
linreg_r2 = r2_score(y_test, linreg_pred)
print(f"MAE of the linear regression model is: {linreg_mae:.2f}")
print(f"MSE of the linear regression model is: {linreg_mse:.2f}")
print(f"R2 score of the linear regression model is: {linreg_r2:.2f}")
# Out:
# MAE of the linear regression model is: 0.39
# MSE of the linear regression model is: 0.24
# R2 score of the linear regression model is: 0.18

# %%
# training by decision tree regressor algorithm
dtree = DecisionTreeRegressor()
dtree.fit(X_train, y_train)
dtree_pred = dtree.predict(X_test)

# %%
#evaluating performance metrics of decision tree
dtree_mae = mean_absolute_error(y_test, dtree_pred)
dtree_mse = mean_squared_error(y_test, dtree_pred)
dtree_r2 = r2_score(y_test, dtree_pred)
print(f"MAE of the decision tree model is: {dtree_mae:.2f}")
print(f"MSE of the decision tree model is: {dtree_mse:.2f}")
print(f"R2 score of the decision tree model is: {dtree_r2:.2f}")
# Out:
# MAE of the decision tree model is: 0.35
# MSE of the decision tree model is: 0.21
# R2 score of the decision tree model is: 0.30

# %%
# training by SVR algorithm
svrmodel = SVR()
svrmodel.fit(X_train, y_train)
svrmodel_pred = svrmodel.predict(X_test)
# Out:
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#evaluating performance metrics of SVR
svrmodel_mae = mean_absolute_error(y_test, svrmodel_pred)
svrmodel_mse = mean_squared_error(y_test, svrmodel_pred)
svrmodel_r2 = r2_score(y_test, svrmodel_pred)
print(f"MAE of the SVR model is: {svrmodel_mae:.2f}")
print(f"MSE of the SVR model is: {svrmodel_mse:.2f}")
print(f"R2 score of the SVR model is: {svrmodel_r2:.2f}")
# Out:
# MAE of the SVR model is: 0.38
# MSE of the SVR model is: 0.23
# R2 score of the SVR model is: 0.22

# %%
# training by Random forest regressor algorithm
rfrmodel = RandomForestRegressor()
rfrmodel.fit(X_train, y_train)
rfrmodel = rfrmodel.predict(X_test)
# Out:
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)

# %%
#evaluating performance metrics of Random forest
rfrmodel_mae = mean_absolute_error(y_test, randomforestpredictions)
rfrmodel_mse = mean_squared_error(y_test, randomforestpredictions)
rfrmodel_r2 = r2_score(y_test, randomforestpredictions)
print(f"MAE of the random forest model is: {rfrmodel_mae:.2f}")
print(f"MSE of the random forest model is: {rfrmodel_mse:.2f}")
print(f"R2 score of the random forest model is: {rfrmodel_r2:.2f}")
# Out:
# MAE of the random forest model is: 0.35
# MSE of the random forest model is: 0.20
# R2 score of the random forest model is: 0.31

# %%
# training by KNeighborsRegressor algorithm
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
knn = knn.predict(X_test)

# %%
#evaluating performance metrics of KNeighborsRegressor
knn_mae = mean_absolute_error(y_test, knnpreds)
knn_mse = mean_squared_error(y_test, knnpreds)
knn_r2 = r2_score(y_test, knnpreds)
print(f"MAE of the K Neighbors Regressor model is: {knn_mae:.2f}")
print(f"MSE of the K Neighbors Regressor model is: {knn_mse:.2f}")
print(f"R2 score of the K Neighbors Regressor model is: {knn_r2:.2f}")
# Out:
# MAE of the K Neighbors Regressor model is: 0.38
# MSE of the K Neighbors Regressor model is: 0.23
# R2 score of the K Neighbors Regressor model is: 0.22

# %%
 # training by AdaBoostRegressor algorithm
ada = AdaBoostRegressor()
ada.fit(X_train, y_train)
ada = ada.predict(X_test)
# Out:
# C:\Users\ABC\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#evaluating performance metrics of AdaBoostRegressor
ada_mae = mean_absolute_error(y_test, adapreds)
ada_mse = mean_squared_error(y_test, adapreds)
ada_r2 = r2_score(y_test, adapreds)
print(f"MAE of the AdaBoost Regressor model is: {knn_mae:.2f}")
print(f"MSE of the AdaBoost Regressor model is: {knn_mse:.2f}")
print(f"R2 score of the AdaBoost Regressor model is: {knn_r2:.2f}")
# Out:
# MAE of the AdaBoost Regressor model is: 0.38
# MSE of the AdaBoost Regressor model is: 0.23
# R2 score of the AdaBoost Regressor model is: 0.22

# %%
#Random Forest model and Decision Tree model are performing well here as compared to rest
